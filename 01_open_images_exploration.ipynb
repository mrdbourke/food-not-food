# %%
import pandas as pd

# %%
classes_df = pd.read_csv("data/open_images/train/metadata/classes.csv", names=["id", "class"])
classes_df
# Out:
#               id       class
# 0      /m/011k07    Tortoise
# 1    /m/011q46kg   Container
# 2      /m/012074      Magpie
# 3      /m/0120dh  Sea turtle
# 4      /m/01226z    Football
# ..           ...         ...
# 596     /m/0qmmr  Wheelchair
# 597   /m/0wdt60w  Rugby ball
# 598      /m/0xfy   Armadillo
# 599     /m/0xzly     Maracas
# 600     /m/0zvk5      Helmet
#
# [601 rows x 2 columns]

# %%
class_list = classes_df["class"].tolist()
class_list[:10]
# Out:
# ['Tortoise',
#  'Container',
#  'Magpie',
#  'Sea turtle',
#  'Football',
#  'Ambulance',
#  'Ladder',
#  'Toothbrush',
#  'Syringe',
#  'Sink']

# %%
with open("data/food_list.txt", "r") as f:
    food_list = f.read().splitlines()
food_list[:10]
# Out:
# ['absinth',
#  'absinthe',
#  'absinthes',
#  'absinths',
#  'acerola',
#  'acerolas',
#  'acetum',
#  'afters',
#  'ail',
#  'ails']

# %%
open_images_food_list = []
for class_name in class_list:
    if class_name.lower() in food_list:
        open_images_food_list.append(class_name)
open_images_food_list
# Out:
# ['Apple',
#  'Beer',
#  'Cucumber',
#  'Radish',
#  'Waffle',
#  'Pancake',
#  'Pretzel',
#  'Bagel',
#  'Popcorn',
#  'Cheese',
#  'Muffin',
#  'Snack',
#  'Juice',
#  'Cookie',
#  'Cocktail',
#  'Dessert',
#  'Drink',
#  'Zucchini',
#  'Coffee',
#  'Food',
#  'Grape',
#  'Artichoke',
#  'Milk',
#  'Mushroom',
#  'Potato',
#  'Pasta',
#  'Pumpkin',
#  'Pear',
#  'Mixer',
#  'Pizza',
#  'Rose',
#  'Seafood',
#  'Tea',
#  'Strawberry',
#  'Tomato',
#  'Wine',
#  'Cream',
#  'Bread',
#  'Chicken',
#  'Squid',
#  'Lemon',
#  'Banana',
#  'Hamburger',
#  'Lobster',
#  'Orange',
#  'Coconut',
#  'Vegetable',
#  'Shellfish',
#  'Cabbage',
#  'Carrot',
#  'Mango',
#  'Pineapple',
#  'Candy',
#  'Salad',
#  'Grinder',
#  'Broccoli',
#  'Pastry',
#  'Pomegranate',
#  'Doughnut',
#  'Watermelon',
#  'Cantaloupe',
#  'Sandwich']

# %%
classes_df["is_food"] = classes_df["class"].isin(open_images_food_list)
classes_df
# Out:
#               id       class  is_food
# 0      /m/011k07    Tortoise    False
# 1    /m/011q46kg   Container    False
# 2      /m/012074      Magpie    False
# 3      /m/0120dh  Sea turtle    False
# 4      /m/01226z    Football    False
# ..           ...         ...      ...
# 596     /m/0qmmr  Wheelchair    False
# 597   /m/0wdt60w  Rugby ball    False
# 598      /m/0xfy   Armadillo    False
# 599     /m/0xzly     Maracas    False
# 600     /m/0zvk5      Helmet    False
#
# [601 rows x 3 columns]

# %%
classes_df.is_food.value_counts()
# Out:
# False    539
# True      62
# Name: is_food, dtype: int64

# %%
open_images_food_df = classes_df[classes_df["is_food"] == True]
open_images_food_df[["id", "class"]].sort_values("class").to_csv("data/open_images_food_classes.csv", header=False, index=False)

# %%
# Now want to read all images from Open Images folder and filter out whether the image 
# is food or not.

# Go through Open Images folder (e.g. open_images/test, train, validation)
# Find all images (in "data") folder
# See whether their classification label is food or not 
# Classification label is in ("data/open_images/*/labels/classification.csv")
# If food, move to food_images, if not, move to non_food_images

# %%
# Get all image paths from open_images folders
import pathlib
image_path_list = list(pathlib.Path("data/open_images/").glob("*/*/*.jpg"))
len(image_path_list)
# Out:
# 300

# %%
image_path_list[:10]
# Out:
# [PosixPath('data/open_images/test/data/a63be9e4ea067c1d.jpg'),
#  PosixPath('data/open_images/test/data/5a82b29382d32edf.jpg'),
#  PosixPath('data/open_images/test/data/504a7622ec7c1fbb.jpg'),
#  PosixPath('data/open_images/test/data/c07f825ff2cf4af1.jpg'),
#  PosixPath('data/open_images/test/data/65fbccdd5c1071a3.jpg'),
#  PosixPath('data/open_images/test/data/90e9af3509ed1263.jpg'),
#  PosixPath('data/open_images/test/data/26c8d263abd19e4d.jpg'),
#  PosixPath('data/open_images/test/data/980d2ed43c5d94ad.jpg'),
#  PosixPath('data/open_images/test/data/d2b6b0832ef9e1d9.jpg'),
#  PosixPath('data/open_images/test/data/030918a2abf658f3.jpg')]

# %%
image_path_list[0].name.split(".")[0]
# Out:
# 'a63be9e4ea067c1d'

# %%
# Get downloaded image IDs
image_ids = [image_path.name.split(".")[0] for image_path in image_path_list]
image_ids[:5]
# Out:
# ['a63be9e4ea067c1d',
#  '5a82b29382d32edf',
#  '504a7622ec7c1fbb',
#  'c07f825ff2cf4af1',
#  '65fbccdd5c1071a3']

# %%
class_label_dict = dict(zip(classes_df["id"], classes_df["class"]))
class_label_dict
# Out:
# {'/m/011k07': 'Tortoise',
#  '/m/011q46kg': 'Container',
#  '/m/012074': 'Magpie',
#  '/m/0120dh': 'Sea turtle',
#  '/m/01226z': 'Football',
#  '/m/012n7d': 'Ambulance',
#  '/m/012w5l': 'Ladder',
#  '/m/012xff': 'Toothbrush',
#  '/m/012ysf': 'Syringe',
#  '/m/0130jx': 'Sink',
#  '/m/0138tl': 'Toy',
#  '/m/013y1f': 'Organ (Musical Instrument)',
#  '/m/01432t': 'Cassette deck',
#  '/m/014j1m': 'Apple',
#  '/m/014sv8': 'Human eye',
#  '/m/014trl': 'Cosmetics',
#  '/m/014y4n': 'Paddle',
#  '/m/0152hh': 'Snowman',
#  '/m/01599': 'Beer',
#  '/m/01_5g': 'Chopsticks',
#  '/m/015h_t': 'Human beard',
#  '/m/015p6': 'Bird',
#  '/m/015qbp': 'Parking meter',
#  '/m/015qff': 'Traffic light',
#  '/m/015wgc': 'Croissant',
#  '/m/015x4r': 'Cucumber',
#  '/m/015x5n': 'Radish',
#  '/m/0162_1': 'Towel',
#  '/m/0167gd': 'Doll',
#  '/m/016m2d': 'Skull',
#  '/m/0174k2': 'Washing machine',
#  '/m/0174n1': 'Glove',
#  '/m/0175cv': 'Tick',
#  '/m/0176mf': 'Belt',
#  '/m/017ftj': 'Sunglasses',
#  '/m/018j2': 'Banjo',
#  '/m/018p4k': 'Cart',
#  '/m/018xm': 'Ball',
#  '/m/01940j': 'Backpack',
#  '/m/0199g': 'Bicycle',
#  '/m/019dx1': 'Home appliance',
#  '/m/019h78': 'Centipede',
#  '/m/019jd': 'Boat',
#  '/m/019w40': 'Surfboard',
#  '/m/01b638': 'Boot',
#  '/m/01b7fy': 'Headphones',
#  '/m/01b9xk': 'Hot dog',
#  '/m/01bfm9': 'Shorts',
#  '/m/01_bhs': 'Fast food',
#  '/m/01bjv': 'Bus',
#  '/m/01bl7v': 'Boy',
#  '/m/01bms0': 'Screwdriver',
#  '/m/01bqk0': 'Bicycle wheel',
#  '/m/01btn': 'Barge',
#  '/m/01c648': 'Laptop',
#  '/m/01cmb2': 'Miniskirt',
#  '/m/01d380': 'Drill (Tool)',
#  '/m/01d40f': 'Dress',
#  '/m/01dws': 'Bear',
#  '/m/01dwsz': 'Waffle',
#  '/m/01dwwc': 'Pancake',
#  '/m/01dxs': 'Brown bear',
#  '/m/01dy8n': 'Woodpecker',
#  '/m/01f8m5': 'Blue jay',
#  '/m/01f91_': 'Pretzel',
#  '/m/01fb_0': 'Bagel',
#  '/m/01fdzj': 'Tower',
#  '/m/01fh4r': 'Teapot',
#  '/m/01g317': 'Person',
#  '/m/01g3x7': 'Bow and arrow',
#  '/m/01gkx_': 'Swimwear',
#  '/m/01gllr': 'Beehive',
#  '/m/01gmv2': 'Brassiere',
#  '/m/01h3n': 'Bee',
#  '/m/01h44': 'Bat (Animal)',
#  '/m/01h8tj': 'Starfish',
#  '/m/01hrv5': 'Popcorn',
#  '/m/01j3zr': 'Burrito',
#  '/m/01j4z9': 'Chainsaw',
#  '/m/01j51': 'Balloon',
#  '/m/01j5ks': 'Wrench',
#  '/m/01j61q': 'Tent',
#  '/m/01jfm_': 'Vehicle registration plate',
#  '/m/01jfsr': 'Lantern',
#  '/m/01k6s3': 'Toaster',
#  '/m/01kb5b': 'Flashlight',
#  '/m/01knjb': 'Billboard',
#  '/m/01krhy': 'Tiara',
#  '/m/01lcw4': 'Limousine',
#  '/m/01llwg': 'Necklace',
#  '/m/01lrl': 'Carnivore',
#  '/m/01lsmm': 'Scissors',
#  '/m/01lynh': 'Stairs',
#  '/m/01m2v': 'Computer keyboard',
#  '/m/01m4t': 'Printer',
#  '/m/01mqdt': 'Traffic sign',
#  '/m/01mzpv': 'Chair',
#  '/m/01n4qj': 'Shirt',
#  '/m/01n5jq': 'Poster',
#  '/m/01nkt': 'Cheese',
#  '/m/01nq26': 'Sock',
#  '/m/01pns0': 'Fire hydrant',
#  '/m/01prls': 'Land vehicle',
#  '/m/01r546': 'Earrings',
#  '/m/01rkbr': 'Tie',
#  '/m/01rzcn': 'Watercraft',
#  '/m/01s105': 'Cabinetry',
#  '/m/01s55n': 'Suitcase',
#  '/m/01tcjp': 'Muffin',
#  '/m/01vbnl': 'Bidet',
#  '/m/01ww8y': 'Snack',
#  '/m/01x3jk': 'Snowmobile',
#  '/m/01x3z': 'Clock',
#  '/m/01xgg_': 'Medical equipment',
#  '/m/01xq0k1': 'Cattle',
#  '/m/01xqw': 'Cello',
#  '/m/01xs3r': 'Jet ski',
#  '/m/01x_v': 'Camel',
#  '/m/01xygc': 'Coat',
#  '/m/01xyhv': 'Suit',
#  '/m/01y9k5': 'Desk',
#  '/m/01yrx': 'Cat',
#  '/m/01yx86': 'Bronze sculpture',
#  '/m/01z1kdw': 'Juice',
#  '/m/02068x': 'Gondola',
#  '/m/020jm': 'Beetle',
#  '/m/020kz': 'Cannon',
#  '/m/020lf': 'Computer mouse',
#  '/m/021mn': 'Cookie',
#  '/m/021sj1': 'Office building',
#  '/m/0220r2': 'Fountain',
#  '/m/0242l': 'Coin',
#  '/m/024d2': 'Calculator',
#  '/m/024g6': 'Cocktail',
#  '/m/02522': 'Computer monitor',
#  '/m/025dyy': 'Box',
#  '/m/025fsf': 'Stapler',
#  '/m/025nd': 'Christmas tree',
#  '/m/025rp__': 'Cowboy hat',
#  '/m/0268lbt': 'Hiking equipment',
#  '/m/026qbn5': 'Studio couch',
#  '/m/026t6': 'Drum',
#  '/m/0270h': 'Dessert',
#  '/m/0271qf7': 'Wine rack',
#  '/m/0271t': 'Drink',
#  '/m/027pcv': 'Zucchini',
#  '/m/027rl48': 'Ladle',
#  '/m/0283dt1': 'Human mouth',
#  '/m/0284d': 'Dairy Product',
#  '/m/029b3': 'Dice',
#  '/m/029bxz': 'Oven',
#  '/m/029tx': 'Dinosaur',
#  '/m/02bm9n': 'Ratchet (Device)',
#  '/m/02crq1': 'Couch',
#  '/m/02ctlc': 'Cricket ball',
#  '/m/02cvgx': 'Winter melon',
#  '/m/02d1br': 'Spatula',
#  '/m/02d9qx': 'Whiteboard',
#  '/m/02ddwp': 'Pencil sharpener',
#  '/m/02dgv': 'Door',
#  '/m/02dl1y': 'Hat',
#  '/m/02f9f_': 'Shower',
#  '/m/02fh7f': 'Eraser',
#  '/m/02fq_6': 'Fedora',
#  '/m/02g30s': 'Guacamole',
#  '/m/02gzp': 'Dagger',
#  '/m/02h19r': 'Scarf',
#  '/m/02hj4': 'Dolphin',
#  '/m/02jfl0': 'Sombrero',
#  '/m/02jnhm': 'Tin can',
#  '/m/02jvh9': 'Mug',
#  '/m/02jz0l': 'Tap',
#  '/m/02l8p9': 'Harbor seal',
#  '/m/02lbcq': 'Stretcher',
#  '/m/02mqfb': 'Can opener',
#  '/m/02_n6y': 'Goggles',
#  '/m/02p0tk3': 'Human body',
#  '/m/02p3w7d': 'Roller skates',
#  '/m/02p5f1q': 'Coffee cup',
#  '/m/02pdsw': 'Cutting board',
#  '/m/02pjr4': 'Blender',
#  '/m/02pkr5': 'Plumbing fixture',
#  '/m/02pv19': 'Stop sign',
#  '/m/02rdsp': 'Office supplies',
#  '/m/02rgn06': 'Volleyball (Ball)',
#  '/m/02s195': 'Vase',
#  '/m/02tsc9': 'Slow cooker',
#  '/m/02vkqh8': 'Wardrobe',
#  '/m/02vqfm': 'Coffee',
#  '/m/02vwcm': 'Whisk',
#  '/m/02w3r3': 'Paper towel',
#  '/m/02w3_ws': 'Personal care',
#  '/m/02wbm': 'Food',
#  '/m/02wbtzl': 'Sun hat',
#  '/m/02wg_p': 'Tree house',
#  '/m/02wmf': 'Flying disc',
#  '/m/02wv6h6': 'Skirt',
#  '/m/02wv84t': 'Gas stove',
#  '/m/02x8cch': 'Salt and pepper shakers',
#  '/m/02x984l': 'Mechanical fan',
#  '/m/02xb7qb': 'Face powder',
#  '/m/02xqq': 'Fax',
#  '/m/02xwb': 'Fruit',
#  '/m/02y6n': 'French fries',
#  '/m/02z51p': 'Nightstand',
#  '/m/02zn6n': 'Barrel',
#  '/m/02zt3': 'Kite',
#  '/m/02zvsm': 'Tart',
#  '/m/030610': 'Treadmill',
#  '/m/0306r': 'Fox',
#  '/m/03120': 'Flag',
#  '/m/0319l': 'French horn',
#  '/m/031b6r': 'Window blind',
#  '/m/031n1': 'Human foot',
#  '/m/0323sq': 'Golf cart',
#  '/m/032b3c': 'Jacket',
#  '/m/033cnk': 'Egg (Food)',
#  '/m/033rq4': 'Street light',
#  '/m/0342h': 'Guitar',
#  '/m/034c16': 'Pillow',
#  '/m/035r7c': 'Human leg',
#  '/m/035vxb': 'Isopod',
#  '/m/0388q': 'Grape',
#  '/m/039xj_': 'Human ear',
#  '/m/03bbps': 'Power plugs and sockets',
#  '/m/03bj1': 'Panda',
#  '/m/03bk1': 'Giraffe',
#  '/m/03bt1vf': 'Woman',
#  '/m/03c7gz': 'Door handle',
#  '/m/03d443': 'Rhinoceros',
#  '/m/03dnzn': 'Bathtub',
#  '/m/03fj2': 'Goldfish',
#  '/m/03fp41': 'Houseplant',
#  '/m/03fwl': 'Goat',
#  '/m/03g8mr': 'Baseball bat',
#  '/m/03grzl': 'Baseball glove',
#  '/m/03hj559': 'Mixing bowl',
#  '/m/03hl4l9': 'Marine invertebrates',
#  '/m/03hlz0c': 'Kitchen utensil',
#  '/m/03jbxj': 'Light switch',
#  '/m/03jm5': 'House',
#  '/m/03k3r': 'Horse',
#  '/m/03kt2w': 'Stationary bicycle',
#  '/m/03l9g': 'Hammer',
#  '/m/03ldnb': 'Ceiling fan',
#  '/m/03m3pdh': 'Sofa bed',
#  '/m/03m3vtv': 'Adhesive tape',
#  '/m/03m5k': 'Harp',
#  '/m/03nfch': 'Sandal',
#  '/m/03p3bw': 'Bicycle helmet',
#  '/m/03q5c7': 'Saucer',
#  '/m/03q5t': 'Harpsichord',
#  '/m/03q69': 'Human hair',
#  '/m/03qhv5': 'Heater',
#  '/m/03qjg': 'Harmonica',
#  '/m/03qrc': 'Hamster',
#  '/m/03rszm': 'Curtain',
#  '/m/03ssj5': 'Bed',
#  '/m/03s_tn': 'Kettle',
#  '/m/03tw93': 'Fireplace',
#  '/m/03txqz': 'Scale',
#  '/m/03v5tg': 'Drinking straw',
#  '/m/03vt0': 'Insect',
#  '/m/03wvsk': 'Hair dryer',
#  '/m/03_wxk': 'Kitchenware',
#  '/m/03wym': 'Indoor rower',
#  '/m/03xxp': 'Invertebrate',
#  '/m/03y6mg': 'Food processor',
#  '/m/03__z0': 'Bookcase',
#  '/m/040b_t': 'Refrigerator',
#  '/m/04169hn': 'Wood-burning stove',
#  '/m/0420v5': 'Punching bag',
#  '/m/043nyj': 'Common fig',
#  '/m/0440zs': 'Cocktail shaker',
#  '/m/0449p': 'Jaguar (Animal)',
#  '/m/044r5d': 'Golf ball',
#  '/m/0463sg': 'Fashion accessory',
#  '/m/046dlr': 'Alarm clock',
#  '/m/047j0r': 'Filing cabinet',
#  '/m/047v4b': 'Artichoke',
#  '/m/04bcr3': 'Table',
#  '/m/04brg2': 'Tableware',
#  '/m/04c0y': 'Kangaroo',
#  '/m/04cp_': 'Koala',
#  '/m/04ctx': 'Knife',
#  '/m/04dr76w': 'Bottle',
#  '/m/04f5ws': 'Bottle opener',
#  '/m/04g2r': 'Lynx',
#  '/m/04gth': 'Lavender (Plant)',
#  '/m/04h7h': 'Lighthouse',
#  '/m/04h8sr': 'Dumbbell',
#  '/m/04hgtk': 'Human head',
#  '/m/04kkgm': 'Bowl',
#  '/m/04lvq_': 'Humidifier',
#  '/m/04m6gz': 'Porch',
#  '/m/04m9y': 'Lizard',
#  '/m/04p0qw': 'Billiard table',
#  '/m/04rky': 'Mammal',
#  '/m/04rmv': 'Mouse',
#  '/m/04_sv': 'Motorcycle',
#  '/m/04szw': 'Musical instrument',
#  '/m/04tn4x': 'Swim cap',
#  '/m/04v6l4': 'Frying pan',
#  '/m/04vv5k': 'Snowplow',
#  '/m/04y4h8h': 'Bathroom cabinet',
#  '/m/04ylt': 'Missile',
#  '/m/04yqq2': 'Bust',
#  '/m/04yx4': 'Man',
#  '/m/04z4wx': 'Waffle iron',
#  '/m/04zpv': 'Milk',
#  '/m/04zwwv': 'Ring binder',
#  '/m/050gv4': 'Plate',
#  '/m/050k8': 'Mobile phone',
#  '/m/052lwg6': 'Baked goods',
#  '/m/052sf': 'Mushroom',
#  '/m/05441v': 'Crutch',
#  '/m/054fyh': 'Pitcher (Container)',
#  '/m/054_l': 'Mirror',
#  '/m/054xkw': 'Personal flotation device',
#  '/m/05_5p_0': 'Table tennis racket',
#  '/m/05676x': 'Pencil case',
#  '/m/057cc': 'Musical keyboard',
#  '/m/057p5t': 'Scoreboard',
#  '/m/0584n8': 'Briefcase',
#  '/m/058qzx': 'Kitchen knife',
#  '/m/05bm6': 'Nail (Construction)',
#  '/m/05ctyq': 'Tennis ball',
#  '/m/05gqfk': 'Plastic bag',
#  '/m/05kms': 'Oboe',
#  '/m/05kyg_': 'Chest of drawers',
#  '/m/05n4y': 'Ostrich',
#  '/m/05r5c': 'Piano',
#  '/m/05r655': 'Girl',
#  '/m/05s2s': 'Plant',
#  '/m/05vtc': 'Potato',
#  '/m/05w9t9': 'Hair spray',
#  '/m/05y5lj': 'Sports equipment',
#  '/m/05z55': 'Pasta',
#  '/m/05z6w': 'Penguin',
#  '/m/05zsy': 'Pumpkin',
#  '/m/061_f': 'Pear',
#  '/m/061hd_': 'Infant bed',
#  '/m/0633h': 'Polar bear',
#  '/m/063rgb': 'Mixer',
#  '/m/0642b4': 'Cupboard',
#  '/m/065h6l': 'Jacuzzi',
#  '/m/0663v': 'Pizza',
#  '/m/06_72j': 'Digital clock',
#  '/m/068zj': 'Pig',
#  '/m/06bt6': 'Reptile',
#  '/m/06c54': 'Rifle',
#  '/m/06c7f7': 'Lipstick',
#  '/m/06_fw': 'Skateboard',
#  '/m/06j2d': 'Raven',
#  '/m/06k2mb': 'High heels',
#  '/m/06l9r': 'Red panda',
#  '/m/06m11': 'Rose',
#  '/m/06mf6': 'Rabbit',
#  '/m/06msq': 'Sculpture',
#  '/m/06ncr': 'Saxophone',
#  '/m/06nrc': 'Shotgun',
#  '/m/06nwz': 'Seafood',
#  '/m/06pcq': 'Submarine sandwich',
#  '/m/06__v': 'Snowboard',
#  '/m/06y5r': 'Sword',
#  '/m/06z37_': 'Picture frame',
#  '/m/07030': 'Sushi',
#  '/m/0703r8': 'Loveseat',
#  '/m/071p9': 'Ski',
#  '/m/071qp': 'Squirrel',
#  '/m/073bxn': 'Tripod',
#  '/m/073g6': 'Stethoscope',
#  '/m/074d1': 'Submarine',
#  '/m/0755b': 'Scorpion',
#  '/m/076bq': 'Segway',
#  '/m/076lb9': 'Training bench',
#  '/m/078jl': 'Snake',
#  '/m/078n6m': 'Coffee table',
#  '/m/079cl': 'Skyscraper',
#  '/m/07bgp': 'Sheep',
#  '/m/07c52': 'Television',
#  '/m/07c6l': 'Trombone',
#  '/m/07clx': 'Tea',
#  '/m/07cmd': 'Tank',
#  '/m/07crc': 'Taco',
#  '/m/07cx4': 'Telephone',
#  '/m/07dd4': 'Torch',
#  '/m/07dm6': 'Tiger',
#  '/m/07fbm7': 'Strawberry',
#  '/m/07gql': 'Trumpet',
#  '/m/07j7r': 'Tree',
#  '/m/07j87': 'Tomato',
#  '/m/07jdr': 'Train',
#  '/m/07k1x': 'Tool',
#  '/m/07kng9': 'Picnic basket',
#  '/m/07mcwg': 'Cooking spray',
#  '/m/07mhn': 'Trousers',
#  '/m/07pj7bq': 'Bowling equipment',
#  '/m/07qxg_': 'Football helmet',
#  '/m/07r04': 'Truck',
#  '/m/07v9_z': 'Measuring cup',
#  '/m/07xyvk': 'Coffeemaker',
#  '/m/07y_7': 'Violin',
#  '/m/07yv9': 'Vehicle',
#  '/m/080hkjn': 'Handbag',
#  '/m/080n7g': 'Paper cutter',
#  '/m/081qc': 'Wine',
#  '/m/083kb': 'Weapon',
#  '/m/083wq': 'Wheel',
#  '/m/084hf': 'Worm',
#  '/m/084rd': 'Wok',
#  '/m/084zz': 'Whale',
#  '/m/0898b': 'Zebra',
#  '/m/08dz3q': 'Auto part',
#  '/m/08hvt4': 'Jug',
#  '/m/08ks85': 'Pizza cutter',
#  '/m/08p92x': 'Cream',
#  '/m/08pbxl': 'Monkey',
#  '/m/096mb': 'Lion',
#  '/m/09728': 'Bread',
#  '/m/099ssp': 'Platter',
#  '/m/09b5t': 'Chicken',
#  '/m/09csl': 'Eagle',
#  '/m/09ct_': 'Helicopter',
#  '/m/09d5_': 'Owl',
#  '/m/09ddx': 'Duck',
#  '/m/09dzg': 'Turtle',
#  '/m/09f20': 'Hippopotamus',
#  '/m/09f_2': 'Crocodile',
#  '/m/09g1w': 'Toilet',
#  '/m/09gtd': 'Toilet paper',
#  '/m/09gys': 'Squid',
#  '/m/09j2d': 'Clothing',
#  '/m/09j5n': 'Footwear',
#  '/m/09k_b': 'Lemon',
#  '/m/09kmb': 'Spider',
#  '/m/09kx5': 'Deer',
#  '/m/09ld4': 'Frog',
#  '/m/09qck': 'Banana',
#  '/m/09rvcxw': 'Rocket',
#  '/m/09tvcd': 'Wine glass',
#  '/m/0b3fp9': 'Countertop',
#  '/m/0bh9flk': 'Tablet computer',
#  '/m/0bjyj5': 'Waste container',
#  '/m/0b_rs': 'Swimming pool',
#  '/m/0bt9lr': 'Dog',
#  '/m/0bt_c3': 'Book',
#  '/m/0bwd_0j': 'Elephant',
#  '/m/0by6g': 'Shark',
#  '/m/0c06p': 'Candle',
#  '/m/0c29q': 'Leopard',
#  '/m/0c2jj': 'Axe',
#  '/m/0c3m8g': 'Hand dryer',
#  '/m/0c3mkw': 'Soap dispenser',
#  '/m/0c568': 'Porcupine',
#  '/m/0c9ph5': 'Flower',
#  '/m/0ccs93': 'Canary',
#  '/m/0cd4d': 'Cheetah',
#  '/m/0cdl1': 'Palm tree',
#  '/m/0cdn1': 'Hamburger',
#  '/m/0cffdh': 'Maple',
#  '/m/0cgh4': 'Building',
#  '/m/0ch_cf': 'Fish',
#  '/m/0cjq5': 'Lobster',
#  '/m/0cjs7': 'Garden Asparagus',
#  '/m/0c_jw': 'Furniture',
#  '/m/0cl4p': 'Hedgehog',
#  '/m/0cmf2': 'Airplane',
#  '/m/0cmx8': 'Spoon',
#  '/m/0cn6p': 'Otter',
#  '/m/0cnyhnx': 'Bull',
#  '/m/0_cp5': 'Oyster',
#  '/m/0cqn2': 'Horizontal bar',
#  '/m/0crjs': 'Convenience store',
#  '/m/0ct4f': 'Bomb',
#  '/m/0cvnqh': 'Bench',
#  '/m/0cxn2': 'Ice cream',
#  '/m/0cydv': 'Caterpillar',
#  '/m/0cyf8': 'Butterfly',
#  '/m/0cyfs': 'Parachute',
#  '/m/0cyhj_': 'Orange',
#  '/m/0czz2': 'Antelope',
#  '/m/0d20w4': 'Beaker',
#  '/m/0d_2m': 'Moths and butterflies',
#  '/m/0d4v4': 'Window',
#  '/m/0d4w1': 'Closet',
#  '/m/0d5gx': 'Castle',
#  '/m/0d8zb': 'Jellyfish',
#  '/m/0dbvp': 'Goose',
#  '/m/0dbzx': 'Mule',
#  '/m/0dftk': 'Swan',
#  '/m/0dj6p': 'Peach',
#  '/m/0djtd': 'Coconut',
#  '/m/0dkzw': 'Seat belt',
#  '/m/0dq75': 'Raccoon',
#  '/m/0_dqb': 'Chisel',
#  '/m/0dt3t': 'Fork',
#  '/m/0dtln': 'Lamp',
#  '/m/0dv5r': 'Camera',
#  '/m/0dv77': 'Squash (Plant)',
#  '/m/0dv9c': 'Racket',
#  '/m/0dzct': 'Human face',
#  '/m/0dzf4': 'Human arm',
#  '/m/0f4s2w': 'Vegetable',
#  '/m/0f571': 'Diaper',
#  '/m/0f6nr': 'Unicycle',
#  '/m/0f6wt': 'Falcon',
#  '/m/0f8s22': 'Chime',
#  '/m/0f9_l': 'Snail',
#  '/m/0fbdv': 'Shellfish',
#  '/m/0fbw6': 'Cabbage',
#  '/m/0fj52s': 'Carrot',
#  '/m/0fldg': 'Mango',
#  '/m/0fly7': 'Jeans',
#  '/m/0fm3zh': 'Flowerpot',
#  '/m/0fp6w': 'Pineapple',
#  '/m/0fqfqc': 'Drawer',
#  '/m/0fqt361': 'Stool',
#  '/m/0frqm': 'Envelope',
#  '/m/0fszt': 'Cake',
#  '/m/0ft9s': 'Dragonfly',
#  '/m/0ftb8': 'Common sunflower',
#  '/m/0fx9l': 'Microwave oven',
#  '/m/0fz0h': 'Honeycomb',
#  '/m/0gd2v': 'Marine mammal',
#  '/m/0gd36': 'Sea lion',
#  '/m/0gj37': 'Ladybug',
#  '/m/0gjbg72': 'Shelf',
#  '/m/0gjkl': 'Watch',
#  '/m/0gm28': 'Candy',
#  '/m/0grw1': 'Salad',
#  '/m/0gv1x': 'Parrot',
#  '/m/0gxl3': 'Handgun',
#  '/m/0h23m': 'Sparrow',
#  '/m/0h2r6': 'Van',
#  '/m/0h8jyh6': 'Grinder',
#  '/m/0h8kx63': 'Spice rack',
#  '/m/0h8l4fh': 'Light bulb',
#  '/m/0h8lkj8': 'Corded phone',
#  '/m/0h8mhzd': 'Sports uniform',
#  '/m/0h8my_4': 'Tennis racket',
#  '/m/0h8mzrc': 'Wall clock',
#  '/m/0h8n27j': 'Serving tray',
#  '/m/0h8n5zk': 'Kitchen & dining room table',
#  '/m/0h8n6f9': 'Dog bed',
#  '/m/0h8n6ft': 'Cake stand',
#  '/m/0h8nm9j': 'Cat furniture',
#  '/m/0h8nr_l': 'Bathroom accessory',
#  '/m/0h8nsvg': 'Facial tissue holder',
#  '/m/0h8ntjv': 'Pressure cooker',
#  '/m/0h99cwc': 'Kitchen appliance',
#  '/m/0h9mv': 'Tire',
#  '/m/0hdln': 'Ruler',
#  '/m/0hf58v5': 'Luggage and bags',
#  '/m/0hg7b': 'Microphone',
#  '/m/0hkxq': 'Broccoli',
#  '/m/0hnnb': 'Umbrella',
#  '/m/0hnyx': 'Pastry',
#  '/m/0hqkz': 'Grapefruit',
#  '/m/0j496': 'Band-aid',
#  '/m/0jbk': 'Animal',
#  '/m/0jg57': 'Bell pepper',
#  '/m/0jly1': 'Turkey',
#  '/m/0jqgx': 'Lily',
#  '/m/0jwn_': 'Pomegranate',
#  '/m/0jy4k': 'Doughnut',
#  '/m/0jyfg': 'Glasses',
#  '/m/0k0pj': 'Human nose',
#  '/m/0k1tl': 'Pen',
#  '/m/0_k2': 'Ant',
#  '/m/0k4j': 'Car',
#  '/m/0k5j': 'Aircraft',
#  '/m/0k65p': 'Human hand',
#  '/m/0km7z': 'Skunk',
#  '/m/0kmg4': 'Teddy bear',
#  '/m/0kpqd': 'Watermelon',
#  '/m/0kpt_': 'Cantaloupe',
#  '/m/0ky7b': 'Dishwasher',
#  '/m/0l14j_': 'Flute',
#  '/m/0l3ms': 'Balance beam',
#  '/m/0l515': 'Sandwich',
#  '/m/0ll1f78': 'Shrimp',
#  '/m/0llzx': 'Sewing machine',
#  '/m/0lt4_': 'Binoculars',
#  '/m/0m53l': 'Rays and skates',
#  '/m/0mcx2': 'Ipod',
#  '/m/0mkg': 'Accordion',
#  '/m/0mw_6': 'Willow',
#  '/m/0n28_': 'Crab',
#  '/m/0nl46': 'Crown',
#  '/m/0nybt': 'Seahorse',
#  '/m/0p833': 'Perfume',
#  '/m/0pcr': 'Alpaca',
#  '/m/0pg52': 'Taxi',
#  '/m/0ph39': 'Canoe',
#  '/m/0qjjc': 'Remote control',
#  '/m/0qmmr': 'Wheelchair',
#  '/m/0wdt60w': 'Rugby ball',
#  '/m/0xfy': 'Armadillo',
#  '/m/0xzly': 'Maracas',
#  '/m/0zvk5': 'Helmet'}

# %% [markdown]
# ## Read in Open Images Label Files with Pandas
#
# Using `pandas` is faster than using `csv`.

# %%
# Get in classification labels
import pathlib
import pandas as pd

data_path = "data/open_images/"
labels_list = list(pathlib.Path(data_path).glob("*/labels/classifications.csv"))
labels_df_list = []
for labels in labels_list:
    df = pd.read_csv(labels)
    labels_df_list.append(df)

labels_df = (pd.concat(labels_df_list, 
             axis=0, 
             ignore_index=True)).drop(["Source", "Confidence"], axis=1)
labels_df.head()
# Out:
#             ImageID  LabelName
# 0  000026e7ee790996   /m/0cgh4
# 1  000026e7ee790996  /m/04hgtk
# 2  000026e7ee790996   /m/0d5gx
# 3  000026e7ee790996   /m/07j7r
# 4  000026e7ee790996   /m/04rky

# %%
len(labels_df)
# Out:
# 10026278

# %%
# Find out whether the test image is downloaded
labels_df["downloaded"] = labels_df["ImageID"].isin(image_ids)

# Get a slice of the labels df of only image IDs that are downloaded
downloaded_labels = labels_df[labels_df["downloaded"] == True].copy()

# Add extra columns to the downloaded labels dataframe
downloaded_labels["class_name"] = downloaded_labels["LabelName"].map(class_label_dict)
downloaded_labels["is_food"] = downloaded_labels["class_name"].isin(open_images_food_list)
downloaded_labels
# Out:
#                    ImageID  LabelName  downloaded        class_name  is_food
# 9597      02f2eb66e7befc62   /m/09j2d        True          Clothing    False
# 9598      02f2eb66e7befc62  /m/08dz3q        True         Auto part    False
# 9599      02f2eb66e7befc62    /m/0k4j        True               Car    False
# 9600      02f2eb66e7befc62   /m/02dgv        True              Door    False
# 9601      02f2eb66e7befc62   /m/083wq        True             Wheel    False
# ...                    ...        ...         ...               ...      ...
# 10023445  fd32639086efad76   /m/083wq        True             Wheel    False
# 10024551  fe44691e02b61fb1   /m/04gth        True  Lavender (Plant)    False
# 10024552  fe44691e02b61fb1   /m/07j7r        True              Tree    False
# 10024553  fe44691e02b61fb1   /m/05s2s        True             Plant    False
# 10024554  fe44691e02b61fb1  /m/0c9ph5        True            Flower    False
#
# [1681 rows x 5 columns]

# %%
len(downloaded_labels)
# Out:
# 1681

# %%
len(downloaded_labels["ImageID"].unique())
# Out:
# 296

# %%
def get_food_and_not_food_image_path_lists(dataframe):
    food_image_path_list = []
    not_food_image_path_list = []
    for i, row in enumerate(dataframe.itertuples(index=False)):
        # Get image details
        image_id = row[0]
        class_name = row[3]
        is_food = row[4]

        # Get image path
        image_path = list(pathlib.Path(data_path).glob("*/*/" + image_id + ".jpg"))[0]
        
        # See if image is food or not
        if is_food:
            food_image_path_list.append(image_path)
        else:
            not_food_image_path_list.append(image_path)

    print(f"Found {len(food_image_path_list)} food image label paths")
    print(f"Found {len(not_food_image_path_list)} not food image label paths")
    print(f"Removing duplicates and food image paths from not food paths...")
    food_image_path_set = set(food_image_path_list)
    # Remove food image paths from not food paths (give food label priority)
    not_food_image_path_set = set(not_food_image_path_list) - food_image_path_set
    print(f"Updated lengths:"
        f"\n-> Food images: {len(food_image_path_set)}"
        f"\n-> Not food images: {len(not_food_image_path_set)}"
        f"\n-> Total images: {len(food_image_path_set) + len(not_food_image_path_set)}")

    return list(food_image_path_set), list(not_food_image_path_set)

# %%
food_image_path_list, not_food_image_path_list = get_food_and_not_food_image_path_lists(dataframe=downloaded_labels)
len(food_image_path_list), len(not_food_image_path_list)
# Out:
# Found 50 food image label paths
# Found 1631 not food image label paths
# Removing duplicates and food image paths from not food paths...
# Updated lengths:
# -> Food images: 29
# -> Not food images: 267
# -> Total images: 296
# (29, 267)

# %%
# Move images to food or not food folder
from shutil import copy2
import os
def copy_image_to_folder(dir_name, image_path, is_food):
    if is_food:
        targ_class = "food_images"
        destination_folder = pathlib.Path(dir_name).joinpath(targ_class)
        if not os.path.exists(destination_folder):
            os.makedirs(destination_folder, exist_ok=True)
        destination_path = pathlib.Path(destination_folder).joinpath(image_path.name)
        print(f"Copying {image_path} to {destination_path}...")
        copy2(image_path, destination_path)
    else:
        targ_class = "not_food_images"
        destination_folder = pathlib.Path(dir_name).joinpath(targ_class)
        if not os.path.exists(destination_folder):
            os.makedirs(destination_folder, exist_ok=True)
        destination_path = pathlib.Path(destination_folder).joinpath(image_path.name)
        print(f"Copying {image_path} to {destination_path}...")
        copy2(image_path, destination_path)

# %%
def copy_image_list_to_folder(dir_name, image_path_list, is_food):
    for i, image_path in enumerate(image_path_list):
        i += 1
        copy_image_to_folder(dir_name=dir_name,
            image_path=image_path,
            is_food=is_food
        )
    print(f"Total {'food' if is_food else 'not_food'} images copied: {i}")

# %%
SAVE_DIR = "data/open_images_extracted"

copy_image_list_to_folder(dir_name=SAVE_DIR,
    image_path_list=food_image_path_list,
    is_food=True
)

copy_image_list_to_folder(dir_name=SAVE_DIR,
    image_path_list=not_food_image_path_list,
    is_food=False
)
# Out:
# Copying data/open_images/validation/data/c1d5dd8b38a5e706.jpg to data/open_images_extracted/food_images/c1d5dd8b38a5e706.jpg...
# Copying data/open_images/train/data/28c4da7eb2924364.jpg to data/open_images_extracted/food_images/28c4da7eb2924364.jpg...
# Copying data/open_images/test/data/0fc0097be2976acb.jpg to data/open_images_extracted/food_images/0fc0097be2976acb.jpg...
# Copying data/open_images/validation/data/468781ab781d74dc.jpg to data/open_images_extracted/food_images/468781ab781d74dc.jpg...
# Copying data/open_images/validation/data/69d4899d910c1478.jpg to data/open_images_extracted/food_images/69d4899d910c1478.jpg...
# Copying data/open_images/validation/data/115150a6ba4eb0ca.jpg to data/open_images_extracted/food_images/115150a6ba4eb0ca.jpg...
# Copying data/open_images/test/data/14cba8a0c786d297.jpg to data/open_images_extracted/food_images/14cba8a0c786d297.jpg...
# Copying data/open_images/train/data/3e386a35b26170be.jpg to data/open_images_extracted/food_images/3e386a35b26170be.jpg...
# Copying data/open_images/test/data/a63be9e4ea067c1d.jpg to data/open_images_extracted/food_images/a63be9e4ea067c1d.jpg...
# Copying data/open_images/test/data/a13b48a3a20165a1.jpg to data/open_images_extracted/food_images/a13b48a3a20165a1.jpg...
# Copying data/open_images/train/data/ba92ac56190b0f45.jpg to data/open_images_extracted/food_images/ba92ac56190b0f45.jpg...
# Copying data/open_images/test/data/980d2ed43c5d94ad.jpg to data/open_images_extracted/food_images/980d2ed43c5d94ad.jpg...
# Copying data/open_images/validation/data/495961f07e0e5b94.jpg to data/open_images_extracted/food_images/495961f07e0e5b94.jpg...
# Copying data/open_images/validation/data/07e6ca03c01ebd0f.jpg to data/open_images_extracted/food_images/07e6ca03c01ebd0f.jpg...
# Copying data/open_images/test/data/8791a4d459a9a174.jpg to data/open_images_extracted/food_images/8791a4d459a9a174.jpg...
# Copying data/open_images/train/data/0a809c82b1542a01.jpg to data/open_images_extracted/food_images/0a809c82b1542a01.jpg...
# Copying data/open_images/test/data/25a8f4f5979207b8.jpg to data/open_images_extracted/food_images/25a8f4f5979207b8.jpg...
# Copying data/open_images/validation/data/b716f6e44403633c.jpg to data/open_images_extracted/food_images/b716f6e44403633c.jpg...
# Copying data/open_images/validation/data/c9c0f756ab63a12c.jpg to data/open_images_extracted/food_images/c9c0f756ab63a12c.jpg...
# Copying data/open_images/validation/data/55551eecc1d1c5d4.jpg to data/open_images_extracted/food_images/55551eecc1d1c5d4.jpg...
# Copying data/open_images/train/data/727a26f3e2948618.jpg to data/open_images_extracted/food_images/727a26f3e2948618.jpg...
# Copying data/open_images/validation/data/8492e5d67d7ac44c.jpg to data/open_images_extracted/food_images/8492e5d67d7ac44c.jpg...
# Copying data/open_images/validation/data/2e3c1cc237a2b9d3.jpg to data/open_images_extracted/food_images/2e3c1cc237a2b9d3.jpg...
# Copying data/open_images/test/data/bcc7de81d492b3e6.jpg to data/open_images_extracted/food_images/bcc7de81d492b3e6.jpg...
# Copying data/open_images/test/data/d2b6b0832ef9e1d9.jpg to data/open_images_extracted/food_images/d2b6b0832ef9e1d9.jpg...
# Copying data/open_images/validation/data/06bc9b828cedce1c.jpg to data/open_images_extracted/food_images/06bc9b828cedce1c.jpg...
# Copying data/open_images/test/data/299ab4f5618495f5.jpg to data/open_images_extracted/food_images/299ab4f5618495f5.jpg...
# Copying data/open_images/train/data/5fd3778ca4729dee.jpg to data/open_images_extracted/food_images/5fd3778ca4729dee.jpg...
# Copying data/open_images/validation/data/e55b0a29516f20c7.jpg to data/open_images_extracted/food_images/e55b0a29516f20c7.jpg...
# Total food images copied: 29
# Copying data/open_images/train/data/47bbd7886138e1f2.jpg to data/open_images_extracted/not_food_images/47bbd7886138e1f2.jpg...
# Copying data/open_images/test/data/1406c2a0650fd4cb.jpg to data/open_images_extracted/not_food_images/1406c2a0650fd4cb.jpg...
# Copying data/open_images/train/data/0cb7427a16e21bc4.jpg to data/open_images_extracted/not_food_images/0cb7427a16e21bc4.jpg...
# Copying data/open_images/train/data/527374fd5de3775f.jpg to data/open_images_extracted/not_food_images/527374fd5de3775f.jpg...
# Copying data/open_images/validation/data/508be9afa6be985f.jpg to data/open_images_extracted/not_food_images/508be9afa6be985f.jpg...
# Copying data/open_images/test/data/3cea50409535ff17.jpg to data/open_images_extracted/not_food_images/3cea50409535ff17.jpg...
# Copying data/open_images/train/data/69f324c604e2d939.jpg to data/open_images_extracted/not_food_images/69f324c604e2d939.jpg...
# Copying data/open_images/test/data/295c1982e5cfc328.jpg to data/open_images_extracted/not_food_images/295c1982e5cfc328.jpg...
# Copying data/open_images/train/data/803fa36a956d8418.jpg to data/open_images_extracted/not_food_images/803fa36a956d8418.jpg...
# Copying data/open_images/train/data/3aa96a5baa04635c.jpg to data/open_images_extracted/not_food_images/3aa96a5baa04635c.jpg...
# Copying data/open_images/test/data/cbe04448f5412590.jpg to data/open_images_extracted/not_food_images/cbe04448f5412590.jpg...
# Copying data/open_images/validation/data/44d5deb3f1eaf618.jpg to data/open_images_extracted/not_food_images/44d5deb3f1eaf618.jpg...
# Copying data/open_images/validation/data/758f3553177b6e69.jpg to data/open_images_extracted/not_food_images/758f3553177b6e69.jpg...
# Copying data/open_images/test/data/081aba3975448701.jpg to data/open_images_extracted/not_food_images/081aba3975448701.jpg...
# Copying data/open_images/validation/data/aa4e1c0cb65b58b9.jpg to data/open_images_extracted/not_food_images/aa4e1c0cb65b58b9.jpg...
# Copying data/open_images/validation/data/ed0a039e8b9f5131.jpg to data/open_images_extracted/not_food_images/ed0a039e8b9f5131.jpg...
# Copying data/open_images/test/data/58329e381c8629be.jpg to data/open_images_extracted/not_food_images/58329e381c8629be.jpg...
# Copying data/open_images/test/data/618aaa18f89b1a91.jpg to data/open_images_extracted/not_food_images/618aaa18f89b1a91.jpg...
# Copying data/open_images/train/data/f26e549597f6ef49.jpg to data/open_images_extracted/not_food_images/f26e549597f6ef49.jpg...
# Copying data/open_images/validation/data/88e283eb5e918a88.jpg to data/open_images_extracted/not_food_images/88e283eb5e918a88.jpg...
# Copying data/open_images/train/data/53ef20958d28ca34.jpg to data/open_images_extracted/not_food_images/53ef20958d28ca34.jpg...
# Copying data/open_images/train/data/5ca307fb9ce44bc6.jpg to data/open_images_extracted/not_food_images/5ca307fb9ce44bc6.jpg...
# Copying data/open_images/validation/data/bb67f1794e815b1e.jpg to data/open_images_extracted/not_food_images/bb67f1794e815b1e.jpg...
# Copying data/open_images/validation/data/6573a18a222fbad1.jpg to data/open_images_extracted/not_food_images/6573a18a222fbad1.jpg...
# Copying data/open_images/train/data/5bcead51b770e8b5.jpg to data/open_images_extracted/not_food_images/5bcead51b770e8b5.jpg...
# Copying data/open_images/validation/data/ae6affe5bc7083fc.jpg to data/open_images_extracted/not_food_images/ae6affe5bc7083fc.jpg...
# Copying data/open_images/validation/data/3c3f56f0afeb7ffc.jpg to data/open_images_extracted/not_food_images/3c3f56f0afeb7ffc.jpg...
# Copying data/open_images/validation/data/2734e597675d8a97.jpg to data/open_images_extracted/not_food_images/2734e597675d8a97.jpg...
# Copying data/open_images/test/data/4790738c0a5c7826.jpg to data/open_images_extracted/not_food_images/4790738c0a5c7826.jpg...
# Copying data/open_images/test/data/f5c76206f2a2808c.jpg to data/open_images_extracted/not_food_images/f5c76206f2a2808c.jpg...
# Copying data/open_images/train/data/29dbacf1cc81cd16.jpg to data/open_images_extracted/not_food_images/29dbacf1cc81cd16.jpg...
# Copying data/open_images/train/data/2c31092e03c6a4b9.jpg to data/open_images_extracted/not_food_images/2c31092e03c6a4b9.jpg...
# Copying data/open_images/train/data/07e670b79bfd96b7.jpg to data/open_images_extracted/not_food_images/07e670b79bfd96b7.jpg...
# Copying data/open_images/test/data/02f2eb66e7befc62.jpg to data/open_images_extracted/not_food_images/02f2eb66e7befc62.jpg...
# Copying data/open_images/validation/data/b0da978fcd699948.jpg to data/open_images_extracted/not_food_images/b0da978fcd699948.jpg...
# Copying data/open_images/validation/data/e5df0358bb1c344c.jpg to data/open_images_extracted/not_food_images/e5df0358bb1c344c.jpg...
# Copying data/open_images/train/data/7c016f99a93c6b0b.jpg to data/open_images_extracted/not_food_images/7c016f99a93c6b0b.jpg...
# Copying data/open_images/train/data/e38144249c2dc238.jpg to data/open_images_extracted/not_food_images/e38144249c2dc238.jpg...
# Copying data/open_images/test/data/38203f98ddc7c854.jpg to data/open_images_extracted/not_food_images/38203f98ddc7c854.jpg...
# Copying data/open_images/train/data/fe0187675852a809.jpg to data/open_images_extracted/not_food_images/fe0187675852a809.jpg...
# Copying data/open_images/train/data/1920a6768bc999ee.jpg to data/open_images_extracted/not_food_images/1920a6768bc999ee.jpg...
# Copying data/open_images/train/data/a8803b15dca3c25f.jpg to data/open_images_extracted/not_food_images/a8803b15dca3c25f.jpg...
# Copying data/open_images/validation/data/86af90e19ef983e2.jpg to data/open_images_extracted/not_food_images/86af90e19ef983e2.jpg...
# Copying data/open_images/validation/data/a3ad91fabd188be3.jpg to data/open_images_extracted/not_food_images/a3ad91fabd188be3.jpg...
# Copying data/open_images/test/data/c00a807de14ed805.jpg to data/open_images_extracted/not_food_images/c00a807de14ed805.jpg...
# Copying data/open_images/train/data/261a3e28bd245291.jpg to data/open_images_extracted/not_food_images/261a3e28bd245291.jpg...
# Copying data/open_images/test/data/0f901c5dcb73e732.jpg to data/open_images_extracted/not_food_images/0f901c5dcb73e732.jpg...
# Copying data/open_images/train/data/9665f17612da6612.jpg to data/open_images_extracted/not_food_images/9665f17612da6612.jpg...
# Copying data/open_images/train/data/d98f506b124a08a2.jpg to data/open_images_extracted/not_food_images/d98f506b124a08a2.jpg...
# Copying data/open_images/train/data/04ddf88d9f7f0054.jpg to data/open_images_extracted/not_food_images/04ddf88d9f7f0054.jpg...
# Copying data/open_images/train/data/14060798627270ed.jpg to data/open_images_extracted/not_food_images/14060798627270ed.jpg...
# Copying data/open_images/validation/data/7f41370fa8018909.jpg to data/open_images_extracted/not_food_images/7f41370fa8018909.jpg...
# Copying data/open_images/test/data/1ef661e308debd80.jpg to data/open_images_extracted/not_food_images/1ef661e308debd80.jpg...
# Copying data/open_images/test/data/b9275b212250fed8.jpg to data/open_images_extracted/not_food_images/b9275b212250fed8.jpg...
# Copying data/open_images/train/data/b1a0db54f2cbef79.jpg to data/open_images_extracted/not_food_images/b1a0db54f2cbef79.jpg...
# Copying data/open_images/train/data/02718e86cefa1dd9.jpg to data/open_images_extracted/not_food_images/02718e86cefa1dd9.jpg...
# Copying data/open_images/test/data/1a563e76489c003b.jpg to data/open_images_extracted/not_food_images/1a563e76489c003b.jpg...
# Copying data/open_images/train/data/1830b07a36d6556b.jpg to data/open_images_extracted/not_food_images/1830b07a36d6556b.jpg...
# Copying data/open_images/train/data/019f495c0dc3708b.jpg to data/open_images_extracted/not_food_images/019f495c0dc3708b.jpg...
# Copying data/open_images/train/data/65104ddb1299b5f1.jpg to data/open_images_extracted/not_food_images/65104ddb1299b5f1.jpg...
# Copying data/open_images/test/data/5dccb60ccb478bc3.jpg to data/open_images_extracted/not_food_images/5dccb60ccb478bc3.jpg...
# Copying data/open_images/train/data/d89d3a17d072dae0.jpg to data/open_images_extracted/not_food_images/d89d3a17d072dae0.jpg...
# Copying data/open_images/validation/data/5d4cd3f05e4d85c4.jpg to data/open_images_extracted/not_food_images/5d4cd3f05e4d85c4.jpg...
# Copying data/open_images/validation/data/8ff25f5ccc3b7717.jpg to data/open_images_extracted/not_food_images/8ff25f5ccc3b7717.jpg...
# Copying data/open_images/test/data/6b75816dfcbb7af7.jpg to data/open_images_extracted/not_food_images/6b75816dfcbb7af7.jpg...
# Copying data/open_images/validation/data/fe44691e02b61fb1.jpg to data/open_images_extracted/not_food_images/fe44691e02b61fb1.jpg...
# Copying data/open_images/validation/data/f227a2e7db78628a.jpg to data/open_images_extracted/not_food_images/f227a2e7db78628a.jpg...
# Copying data/open_images/validation/data/fb27624ed51de5f3.jpg to data/open_images_extracted/not_food_images/fb27624ed51de5f3.jpg...
# Copying data/open_images/validation/data/8c9a7e278dfe01ac.jpg to data/open_images_extracted/not_food_images/8c9a7e278dfe01ac.jpg...
# Copying data/open_images/test/data/6e0f3895aca685af.jpg to data/open_images_extracted/not_food_images/6e0f3895aca685af.jpg...
# Copying data/open_images/train/data/5e92e3021854b1c5.jpg to data/open_images_extracted/not_food_images/5e92e3021854b1c5.jpg...
# Copying data/open_images/train/data/cebdcba334d96dd6.jpg to data/open_images_extracted/not_food_images/cebdcba334d96dd6.jpg...
# Copying data/open_images/test/data/eba3420f8d5ef222.jpg to data/open_images_extracted/not_food_images/eba3420f8d5ef222.jpg...
# Copying data/open_images/test/data/c07f825ff2cf4af1.jpg to data/open_images_extracted/not_food_images/c07f825ff2cf4af1.jpg...
# Copying data/open_images/train/data/5d0f4f5d967a29d7.jpg to data/open_images_extracted/not_food_images/5d0f4f5d967a29d7.jpg...
# Copying data/open_images/test/data/99e6b2e3c3cfda19.jpg to data/open_images_extracted/not_food_images/99e6b2e3c3cfda19.jpg...
# Copying data/open_images/validation/data/53b69ccde22f7bb6.jpg to data/open_images_extracted/not_food_images/53b69ccde22f7bb6.jpg...
# Copying data/open_images/train/data/c8b2ea7861e495fb.jpg to data/open_images_extracted/not_food_images/c8b2ea7861e495fb.jpg...
# Copying data/open_images/test/data/030918a2abf658f3.jpg to data/open_images_extracted/not_food_images/030918a2abf658f3.jpg...
# Copying data/open_images/train/data/b5bc6da5c057856b.jpg to data/open_images_extracted/not_food_images/b5bc6da5c057856b.jpg...
# Copying data/open_images/validation/data/f6a381b5d53c95da.jpg to data/open_images_extracted/not_food_images/f6a381b5d53c95da.jpg...
# Copying data/open_images/train/data/0cd3eef40dd3b1e6.jpg to data/open_images_extracted/not_food_images/0cd3eef40dd3b1e6.jpg...
# Copying data/open_images/train/data/a823e469e0504332.jpg to data/open_images_extracted/not_food_images/a823e469e0504332.jpg...
# Copying data/open_images/test/data/da4ffe66ae18902f.jpg to data/open_images_extracted/not_food_images/da4ffe66ae18902f.jpg...
# Copying data/open_images/train/data/1f40bddcef30b0e7.jpg to data/open_images_extracted/not_food_images/1f40bddcef30b0e7.jpg...
# Copying data/open_images/train/data/d8f56fed204aaea0.jpg to data/open_images_extracted/not_food_images/d8f56fed204aaea0.jpg...
# Copying data/open_images/test/data/3d3b4b9efc103569.jpg to data/open_images_extracted/not_food_images/3d3b4b9efc103569.jpg...
# Copying data/open_images/test/data/66468bd946eb5c3a.jpg to data/open_images_extracted/not_food_images/66468bd946eb5c3a.jpg...
# Copying data/open_images/validation/data/52590bd746122a6d.jpg to data/open_images_extracted/not_food_images/52590bd746122a6d.jpg...
# Copying data/open_images/train/data/1b04d99f22544528.jpg to data/open_images_extracted/not_food_images/1b04d99f22544528.jpg...
# Copying data/open_images/train/data/d4fed81332800b8a.jpg to data/open_images_extracted/not_food_images/d4fed81332800b8a.jpg...
# Copying data/open_images/test/data/26c8d263abd19e4d.jpg to data/open_images_extracted/not_food_images/26c8d263abd19e4d.jpg...
# Copying data/open_images/validation/data/1c1b0a557c797266.jpg to data/open_images_extracted/not_food_images/1c1b0a557c797266.jpg...
# Copying data/open_images/test/data/1b499b5c0f329dfd.jpg to data/open_images_extracted/not_food_images/1b499b5c0f329dfd.jpg...
# Copying data/open_images/test/data/1821114534e17848.jpg to data/open_images_extracted/not_food_images/1821114534e17848.jpg...
# Copying data/open_images/test/data/31bd5c376f96753b.jpg to data/open_images_extracted/not_food_images/31bd5c376f96753b.jpg...
# Copying data/open_images/test/data/3e3169071c91e1cf.jpg to data/open_images_extracted/not_food_images/3e3169071c91e1cf.jpg...
# Copying data/open_images/validation/data/81e659a829d44a47.jpg to data/open_images_extracted/not_food_images/81e659a829d44a47.jpg...
# Copying data/open_images/test/data/3a992fe19a58dc61.jpg to data/open_images_extracted/not_food_images/3a992fe19a58dc61.jpg...
# Copying data/open_images/validation/data/b7357f613dca9ee6.jpg to data/open_images_extracted/not_food_images/b7357f613dca9ee6.jpg...
# Copying data/open_images/train/data/3e16cac3193029fc.jpg to data/open_images_extracted/not_food_images/3e16cac3193029fc.jpg...
# Copying data/open_images/validation/data/3dd1d991aaac9924.jpg to data/open_images_extracted/not_food_images/3dd1d991aaac9924.jpg...
# Copying data/open_images/test/data/2d01d309e5e8082b.jpg to data/open_images_extracted/not_food_images/2d01d309e5e8082b.jpg...
# Copying data/open_images/validation/data/6884cc806a34f5f9.jpg to data/open_images_extracted/not_food_images/6884cc806a34f5f9.jpg...
# Copying data/open_images/test/data/1521f993a99f8738.jpg to data/open_images_extracted/not_food_images/1521f993a99f8738.jpg...
# Copying data/open_images/validation/data/002d1dd67c722d98.jpg to data/open_images_extracted/not_food_images/002d1dd67c722d98.jpg...
# Copying data/open_images/train/data/27ceca64f93c4cd5.jpg to data/open_images_extracted/not_food_images/27ceca64f93c4cd5.jpg...
# Copying data/open_images/test/data/c50adca3bff5ae5e.jpg to data/open_images_extracted/not_food_images/c50adca3bff5ae5e.jpg...
# Copying data/open_images/test/data/d38bdadb4640b7c6.jpg to data/open_images_extracted/not_food_images/d38bdadb4640b7c6.jpg...
# Copying data/open_images/validation/data/5fb7bc6623326460.jpg to data/open_images_extracted/not_food_images/5fb7bc6623326460.jpg...
# Copying data/open_images/train/data/a53d9bca15bcbd19.jpg to data/open_images_extracted/not_food_images/a53d9bca15bcbd19.jpg...
# Copying data/open_images/test/data/13c568997bebd595.jpg to data/open_images_extracted/not_food_images/13c568997bebd595.jpg...
# Copying data/open_images/validation/data/9a66390330794845.jpg to data/open_images_extracted/not_food_images/9a66390330794845.jpg...
# Copying data/open_images/validation/data/ac36d564ad0b93e1.jpg to data/open_images_extracted/not_food_images/ac36d564ad0b93e1.jpg...
# Copying data/open_images/validation/data/38b9976435decaa2.jpg to data/open_images_extracted/not_food_images/38b9976435decaa2.jpg...
# Copying data/open_images/validation/data/1945670f70fff94f.jpg to data/open_images_extracted/not_food_images/1945670f70fff94f.jpg...
# Copying data/open_images/test/data/81df76e75df0f178.jpg to data/open_images_extracted/not_food_images/81df76e75df0f178.jpg...
# Copying data/open_images/train/data/b644897b9ef6c675.jpg to data/open_images_extracted/not_food_images/b644897b9ef6c675.jpg...
# Copying data/open_images/validation/data/cdb64b4f6e894b05.jpg to data/open_images_extracted/not_food_images/cdb64b4f6e894b05.jpg...
# Copying data/open_images/test/data/465fdbe4f2ba5553.jpg to data/open_images_extracted/not_food_images/465fdbe4f2ba5553.jpg...
# Copying data/open_images/train/data/31fef72b4485d2d1.jpg to data/open_images_extracted/not_food_images/31fef72b4485d2d1.jpg...
# Copying data/open_images/train/data/e0b541495987e29c.jpg to data/open_images_extracted/not_food_images/e0b541495987e29c.jpg...
# Copying data/open_images/validation/data/f84712b0b5452cdb.jpg to data/open_images_extracted/not_food_images/f84712b0b5452cdb.jpg...
# Copying data/open_images/train/data/44bf741b6d200c73.jpg to data/open_images_extracted/not_food_images/44bf741b6d200c73.jpg...
# Copying data/open_images/validation/data/e3daec19c41eeddb.jpg to data/open_images_extracted/not_food_images/e3daec19c41eeddb.jpg...
# Copying data/open_images/test/data/15de5f378b5f57d2.jpg to data/open_images_extracted/not_food_images/15de5f378b5f57d2.jpg...
# Copying data/open_images/test/data/559fa790f31c4189.jpg to data/open_images_extracted/not_food_images/559fa790f31c4189.jpg...
# Copying data/open_images/test/data/19c0a15f1010d1e7.jpg to data/open_images_extracted/not_food_images/19c0a15f1010d1e7.jpg...
# Copying data/open_images/test/data/d2188fae96816c96.jpg to data/open_images_extracted/not_food_images/d2188fae96816c96.jpg...
# Copying data/open_images/validation/data/4552c6dac212d85b.jpg to data/open_images_extracted/not_food_images/4552c6dac212d85b.jpg...
# Copying data/open_images/test/data/1c75548b42487be6.jpg to data/open_images_extracted/not_food_images/1c75548b42487be6.jpg...
# Copying data/open_images/test/data/8d352ccbf0eb3de1.jpg to data/open_images_extracted/not_food_images/8d352ccbf0eb3de1.jpg...
# Copying data/open_images/test/data/773188b84bc43aa6.jpg to data/open_images_extracted/not_food_images/773188b84bc43aa6.jpg...
# Copying data/open_images/test/data/504a7622ec7c1fbb.jpg to data/open_images_extracted/not_food_images/504a7622ec7c1fbb.jpg...
# Copying data/open_images/test/data/36fb60de113a8b65.jpg to data/open_images_extracted/not_food_images/36fb60de113a8b65.jpg...
# Copying data/open_images/validation/data/05e70c81443ec40c.jpg to data/open_images_extracted/not_food_images/05e70c81443ec40c.jpg...
# Copying data/open_images/train/data/cb922f426628dc21.jpg to data/open_images_extracted/not_food_images/cb922f426628dc21.jpg...
# Copying data/open_images/test/data/dae40237931b5894.jpg to data/open_images_extracted/not_food_images/dae40237931b5894.jpg...
# Copying data/open_images/validation/data/709ec67ac4a83a2b.jpg to data/open_images_extracted/not_food_images/709ec67ac4a83a2b.jpg...
# Copying data/open_images/test/data/5e0ed7ff1154dc16.jpg to data/open_images_extracted/not_food_images/5e0ed7ff1154dc16.jpg...
# Copying data/open_images/test/data/869cbfe0204ccdf2.jpg to data/open_images_extracted/not_food_images/869cbfe0204ccdf2.jpg...
# Copying data/open_images/train/data/9756e8284b549307.jpg to data/open_images_extracted/not_food_images/9756e8284b549307.jpg...
# Copying data/open_images/train/data/4c8e82360c1b513d.jpg to data/open_images_extracted/not_food_images/4c8e82360c1b513d.jpg...
# Copying data/open_images/test/data/9f899603b45feaec.jpg to data/open_images_extracted/not_food_images/9f899603b45feaec.jpg...
# Copying data/open_images/train/data/2f7050ea24b3816d.jpg to data/open_images_extracted/not_food_images/2f7050ea24b3816d.jpg...
# Copying data/open_images/validation/data/44737cbb05c011be.jpg to data/open_images_extracted/not_food_images/44737cbb05c011be.jpg...
# Copying data/open_images/train/data/87b1e81a4ffad303.jpg to data/open_images_extracted/not_food_images/87b1e81a4ffad303.jpg...
# Copying data/open_images/validation/data/f02151f1decdf23a.jpg to data/open_images_extracted/not_food_images/f02151f1decdf23a.jpg...
# Copying data/open_images/train/data/ee7a0e5e475f847e.jpg to data/open_images_extracted/not_food_images/ee7a0e5e475f847e.jpg...
# Copying data/open_images/test/data/f95a3eea5dcab40b.jpg to data/open_images_extracted/not_food_images/f95a3eea5dcab40b.jpg...
# Copying data/open_images/validation/data/1326b7f63f97c3a4.jpg to data/open_images_extracted/not_food_images/1326b7f63f97c3a4.jpg...
# Copying data/open_images/validation/data/8032bd9ef22ba5c1.jpg to data/open_images_extracted/not_food_images/8032bd9ef22ba5c1.jpg...
# Copying data/open_images/test/data/9560082fdd029217.jpg to data/open_images_extracted/not_food_images/9560082fdd029217.jpg...
# Copying data/open_images/validation/data/e363fd8dbc750911.jpg to data/open_images_extracted/not_food_images/e363fd8dbc750911.jpg...
# Copying data/open_images/validation/data/86ae5a57c8d09d34.jpg to data/open_images_extracted/not_food_images/86ae5a57c8d09d34.jpg...
# Copying data/open_images/validation/data/a91e88cf66ea7d49.jpg to data/open_images_extracted/not_food_images/a91e88cf66ea7d49.jpg...
# Copying data/open_images/train/data/4732696deb01cf8e.jpg to data/open_images_extracted/not_food_images/4732696deb01cf8e.jpg...
# Copying data/open_images/validation/data/e8788a121e93ff6b.jpg to data/open_images_extracted/not_food_images/e8788a121e93ff6b.jpg...
# Copying data/open_images/train/data/a6f2dfdb275217bc.jpg to data/open_images_extracted/not_food_images/a6f2dfdb275217bc.jpg...
# Copying data/open_images/train/data/da918ca6de189700.jpg to data/open_images_extracted/not_food_images/da918ca6de189700.jpg...
# Copying data/open_images/test/data/dabb9fce7928b2e5.jpg to data/open_images_extracted/not_food_images/dabb9fce7928b2e5.jpg...
# Copying data/open_images/test/data/5a6ba94604bb2cd0.jpg to data/open_images_extracted/not_food_images/5a6ba94604bb2cd0.jpg...
# Copying data/open_images/test/data/7b52df7deadc10ca.jpg to data/open_images_extracted/not_food_images/7b52df7deadc10ca.jpg...
# Copying data/open_images/validation/data/ceab5b53fc810771.jpg to data/open_images_extracted/not_food_images/ceab5b53fc810771.jpg...
# Copying data/open_images/test/data/35eb923d4abe65cf.jpg to data/open_images_extracted/not_food_images/35eb923d4abe65cf.jpg...
# Copying data/open_images/test/data/c118bc35e9b3bd4d.jpg to data/open_images_extracted/not_food_images/c118bc35e9b3bd4d.jpg...
# Copying data/open_images/validation/data/b38354f62093ee73.jpg to data/open_images_extracted/not_food_images/b38354f62093ee73.jpg...
# Copying data/open_images/test/data/5baade28b158a6c5.jpg to data/open_images_extracted/not_food_images/5baade28b158a6c5.jpg...
# Copying data/open_images/validation/data/57f147b952b601f7.jpg to data/open_images_extracted/not_food_images/57f147b952b601f7.jpg...
# Copying data/open_images/validation/data/32140fb10f4fd580.jpg to data/open_images_extracted/not_food_images/32140fb10f4fd580.jpg...
# Copying data/open_images/validation/data/6bfd9b18f15962ef.jpg to data/open_images_extracted/not_food_images/6bfd9b18f15962ef.jpg...
# Copying data/open_images/train/data/ed822b88d2b5572f.jpg to data/open_images_extracted/not_food_images/ed822b88d2b5572f.jpg...
# Copying data/open_images/validation/data/e5fc5fee0ab04ce8.jpg to data/open_images_extracted/not_food_images/e5fc5fee0ab04ce8.jpg...
# Copying data/open_images/train/data/9b85b42b80c983de.jpg to data/open_images_extracted/not_food_images/9b85b42b80c983de.jpg...
# Copying data/open_images/test/data/cdb1f7b61e51221f.jpg to data/open_images_extracted/not_food_images/cdb1f7b61e51221f.jpg...
# Copying data/open_images/test/data/e5ac065aa5e9cf45.jpg to data/open_images_extracted/not_food_images/e5ac065aa5e9cf45.jpg...
# Copying data/open_images/validation/data/fd32639086efad76.jpg to data/open_images_extracted/not_food_images/fd32639086efad76.jpg...
# Copying data/open_images/validation/data/4d7417baaedf36d6.jpg to data/open_images_extracted/not_food_images/4d7417baaedf36d6.jpg...
# Copying data/open_images/validation/data/e06fdfa6df3b33d1.jpg to data/open_images_extracted/not_food_images/e06fdfa6df3b33d1.jpg...
# Copying data/open_images/validation/data/bc65337350618b64.jpg to data/open_images_extracted/not_food_images/bc65337350618b64.jpg...
# Copying data/open_images/validation/data/9893ae3d876f9c1c.jpg to data/open_images_extracted/not_food_images/9893ae3d876f9c1c.jpg...
# Copying data/open_images/test/data/91d3ab02785e48de.jpg to data/open_images_extracted/not_food_images/91d3ab02785e48de.jpg...
# Copying data/open_images/train/data/dcaa32bb94a40f95.jpg to data/open_images_extracted/not_food_images/dcaa32bb94a40f95.jpg...
# Copying data/open_images/validation/data/b29791de690639dd.jpg to data/open_images_extracted/not_food_images/b29791de690639dd.jpg...
# Copying data/open_images/test/data/d3035fce3c8620f5.jpg to data/open_images_extracted/not_food_images/d3035fce3c8620f5.jpg...
# Copying data/open_images/test/data/14dbcc674a85d175.jpg to data/open_images_extracted/not_food_images/14dbcc674a85d175.jpg...
# Copying data/open_images/train/data/fd7d0f907465320e.jpg to data/open_images_extracted/not_food_images/fd7d0f907465320e.jpg...
# Copying data/open_images/validation/data/25459eef01dfa715.jpg to data/open_images_extracted/not_food_images/25459eef01dfa715.jpg...
# Copying data/open_images/validation/data/4dc9e5ff5b780f28.jpg to data/open_images_extracted/not_food_images/4dc9e5ff5b780f28.jpg...
# Copying data/open_images/validation/data/3241f09a8964ddfb.jpg to data/open_images_extracted/not_food_images/3241f09a8964ddfb.jpg...
# Copying data/open_images/train/data/31ce8c2f98492885.jpg to data/open_images_extracted/not_food_images/31ce8c2f98492885.jpg...
# Copying data/open_images/validation/data/87a618d5e8e769f4.jpg to data/open_images_extracted/not_food_images/87a618d5e8e769f4.jpg...
# Copying data/open_images/test/data/90e9af3509ed1263.jpg to data/open_images_extracted/not_food_images/90e9af3509ed1263.jpg...
# Copying data/open_images/train/data/0312f5c5cceb4f8a.jpg to data/open_images_extracted/not_food_images/0312f5c5cceb4f8a.jpg...
# Copying data/open_images/train/data/0cc1eb4dedc281e2.jpg to data/open_images_extracted/not_food_images/0cc1eb4dedc281e2.jpg...
# Copying data/open_images/validation/data/8bf07f53c0d58f99.jpg to data/open_images_extracted/not_food_images/8bf07f53c0d58f99.jpg...
# Copying data/open_images/test/data/20a8ef4b1867143a.jpg to data/open_images_extracted/not_food_images/20a8ef4b1867143a.jpg...
# Copying data/open_images/test/data/459f8920f3e4b829.jpg to data/open_images_extracted/not_food_images/459f8920f3e4b829.jpg...
# Copying data/open_images/test/data/f49ba3ffb021dbc3.jpg to data/open_images_extracted/not_food_images/f49ba3ffb021dbc3.jpg...
# Copying data/open_images/validation/data/8b83248fc926c752.jpg to data/open_images_extracted/not_food_images/8b83248fc926c752.jpg...
# Copying data/open_images/train/data/03181223e001dc89.jpg to data/open_images_extracted/not_food_images/03181223e001dc89.jpg...
# Copying data/open_images/train/data/12e72d3d47622b46.jpg to data/open_images_extracted/not_food_images/12e72d3d47622b46.jpg...
# Copying data/open_images/train/data/f9cdca7101c0c8d3.jpg to data/open_images_extracted/not_food_images/f9cdca7101c0c8d3.jpg...
# Copying data/open_images/train/data/e85608634bbde5d2.jpg to data/open_images_extracted/not_food_images/e85608634bbde5d2.jpg...
# Copying data/open_images/train/data/7b9c117280fe2028.jpg to data/open_images_extracted/not_food_images/7b9c117280fe2028.jpg...
# Copying data/open_images/validation/data/56706598d1353742.jpg to data/open_images_extracted/not_food_images/56706598d1353742.jpg...
# Copying data/open_images/train/data/d4b54fcb5731f3d9.jpg to data/open_images_extracted/not_food_images/d4b54fcb5731f3d9.jpg...
# Copying data/open_images/validation/data/8e72808537176248.jpg to data/open_images_extracted/not_food_images/8e72808537176248.jpg...
# Copying data/open_images/test/data/71673ca58a26e5c5.jpg to data/open_images_extracted/not_food_images/71673ca58a26e5c5.jpg...
# Copying data/open_images/train/data/0988f85586993f70.jpg to data/open_images_extracted/not_food_images/0988f85586993f70.jpg...
# Copying data/open_images/test/data/ea1bdc496534afd8.jpg to data/open_images_extracted/not_food_images/ea1bdc496534afd8.jpg...
# Copying data/open_images/train/data/7372af57ec6fce4d.jpg to data/open_images_extracted/not_food_images/7372af57ec6fce4d.jpg...
# Copying data/open_images/validation/data/fc35f7f7ed975c5b.jpg to data/open_images_extracted/not_food_images/fc35f7f7ed975c5b.jpg...
# Copying data/open_images/train/data/2e4fc775be50eb28.jpg to data/open_images_extracted/not_food_images/2e4fc775be50eb28.jpg...
# Copying data/open_images/test/data/5a82b29382d32edf.jpg to data/open_images_extracted/not_food_images/5a82b29382d32edf.jpg...
# Copying data/open_images/validation/data/579b7db14922fee5.jpg to data/open_images_extracted/not_food_images/579b7db14922fee5.jpg...
# Copying data/open_images/validation/data/474d01057a719339.jpg to data/open_images_extracted/not_food_images/474d01057a719339.jpg...
# Copying data/open_images/train/data/cf69cd428be37e45.jpg to data/open_images_extracted/not_food_images/cf69cd428be37e45.jpg...
# Copying data/open_images/test/data/2984a36d00b8c921.jpg to data/open_images_extracted/not_food_images/2984a36d00b8c921.jpg...
# Copying data/open_images/test/data/c0ef03710df0a6f1.jpg to data/open_images_extracted/not_food_images/c0ef03710df0a6f1.jpg...
# Copying data/open_images/train/data/56bebcec0bab3c14.jpg to data/open_images_extracted/not_food_images/56bebcec0bab3c14.jpg...
# Copying data/open_images/test/data/177d36ab867b6d26.jpg to data/open_images_extracted/not_food_images/177d36ab867b6d26.jpg...
# Copying data/open_images/test/data/dc3066a7a24c0434.jpg to data/open_images_extracted/not_food_images/dc3066a7a24c0434.jpg...
# Copying data/open_images/test/data/6d7433b4c9a6b24a.jpg to data/open_images_extracted/not_food_images/6d7433b4c9a6b24a.jpg...
# Copying data/open_images/train/data/1121a6518b8c5956.jpg to data/open_images_extracted/not_food_images/1121a6518b8c5956.jpg...
# Copying data/open_images/validation/data/ef20ea5436f7dc28.jpg to data/open_images_extracted/not_food_images/ef20ea5436f7dc28.jpg...
# Copying data/open_images/train/data/9e82651e214a25c8.jpg to data/open_images_extracted/not_food_images/9e82651e214a25c8.jpg...
# Copying data/open_images/test/data/09f44b955b5a9357.jpg to data/open_images_extracted/not_food_images/09f44b955b5a9357.jpg...
# Copying data/open_images/train/data/4332cd67432ab221.jpg to data/open_images_extracted/not_food_images/4332cd67432ab221.jpg...
# Copying data/open_images/validation/data/029664e65dfb2149.jpg to data/open_images_extracted/not_food_images/029664e65dfb2149.jpg...
# Copying data/open_images/train/data/6c7624322b04ce43.jpg to data/open_images_extracted/not_food_images/6c7624322b04ce43.jpg...
# Copying data/open_images/train/data/a9ab891222603c8e.jpg to data/open_images_extracted/not_food_images/a9ab891222603c8e.jpg...
# Copying data/open_images/validation/data/9d60b6e6e4197080.jpg to data/open_images_extracted/not_food_images/9d60b6e6e4197080.jpg...
# Copying data/open_images/train/data/a76c725abb1f5cdd.jpg to data/open_images_extracted/not_food_images/a76c725abb1f5cdd.jpg...
# Copying data/open_images/test/data/aa0c4af0a9403e57.jpg to data/open_images_extracted/not_food_images/aa0c4af0a9403e57.jpg...
# Copying data/open_images/validation/data/94f5a86622542566.jpg to data/open_images_extracted/not_food_images/94f5a86622542566.jpg...
# Copying data/open_images/test/data/f7f599717306a8d9.jpg to data/open_images_extracted/not_food_images/f7f599717306a8d9.jpg...
# Copying data/open_images/validation/data/1f74ce3e07a2ffd4.jpg to data/open_images_extracted/not_food_images/1f74ce3e07a2ffd4.jpg...
# Copying data/open_images/validation/data/522e36b16a1539a6.jpg to data/open_images_extracted/not_food_images/522e36b16a1539a6.jpg...
# Copying data/open_images/train/data/f061ca8ebc603744.jpg to data/open_images_extracted/not_food_images/f061ca8ebc603744.jpg...
# Copying data/open_images/validation/data/faa179618cd3e38d.jpg to data/open_images_extracted/not_food_images/faa179618cd3e38d.jpg...
# Copying data/open_images/test/data/a12a86e4d354bb71.jpg to data/open_images_extracted/not_food_images/a12a86e4d354bb71.jpg...
# Copying data/open_images/test/data/928ae92fd15c4484.jpg to data/open_images_extracted/not_food_images/928ae92fd15c4484.jpg...
# Copying data/open_images/validation/data/b2ef1761646051e9.jpg to data/open_images_extracted/not_food_images/b2ef1761646051e9.jpg...
# Copying data/open_images/validation/data/7c7c0e2bb9ea0927.jpg to data/open_images_extracted/not_food_images/7c7c0e2bb9ea0927.jpg...
# Copying data/open_images/validation/data/d84441b921f2813c.jpg to data/open_images_extracted/not_food_images/d84441b921f2813c.jpg...
# Copying data/open_images/train/data/f521352f2e67531b.jpg to data/open_images_extracted/not_food_images/f521352f2e67531b.jpg...
# Copying data/open_images/test/data/bacd90ecf8dec38c.jpg to data/open_images_extracted/not_food_images/bacd90ecf8dec38c.jpg...
# Copying data/open_images/train/data/8a897fc1921af67a.jpg to data/open_images_extracted/not_food_images/8a897fc1921af67a.jpg...
# Copying data/open_images/validation/data/8f9001d9470b412d.jpg to data/open_images_extracted/not_food_images/8f9001d9470b412d.jpg...
# Copying data/open_images/validation/data/f14f17cd97f06d27.jpg to data/open_images_extracted/not_food_images/f14f17cd97f06d27.jpg...
# Copying data/open_images/train/data/6cdad98c6e55aa2b.jpg to data/open_images_extracted/not_food_images/6cdad98c6e55aa2b.jpg...
# Copying data/open_images/train/data/1d94320f626fbbc7.jpg to data/open_images_extracted/not_food_images/1d94320f626fbbc7.jpg...
# Copying data/open_images/train/data/a6cf4f70c282a068.jpg to data/open_images_extracted/not_food_images/a6cf4f70c282a068.jpg...
# Copying data/open_images/test/data/0aeec418f212ef2c.jpg to data/open_images_extracted/not_food_images/0aeec418f212ef2c.jpg...
# Copying data/open_images/train/data/9f7fb04f1bf673ca.jpg to data/open_images_extracted/not_food_images/9f7fb04f1bf673ca.jpg...
# Copying data/open_images/train/data/d1aa6c11f04ec66c.jpg to data/open_images_extracted/not_food_images/d1aa6c11f04ec66c.jpg...
# Copying data/open_images/train/data/884feccabf5a71ae.jpg to data/open_images_extracted/not_food_images/884feccabf5a71ae.jpg...
# Copying data/open_images/train/data/3ffa18fb38856f9f.jpg to data/open_images_extracted/not_food_images/3ffa18fb38856f9f.jpg...
# Copying data/open_images/train/data/051c3a546d808b9e.jpg to data/open_images_extracted/not_food_images/051c3a546d808b9e.jpg...
# Copying data/open_images/test/data/97519921d3542ca4.jpg to data/open_images_extracted/not_food_images/97519921d3542ca4.jpg...
# Copying data/open_images/train/data/08b1d83f5227d8fb.jpg to data/open_images_extracted/not_food_images/08b1d83f5227d8fb.jpg...
# Copying data/open_images/train/data/475a65c409e89e29.jpg to data/open_images_extracted/not_food_images/475a65c409e89e29.jpg...
# Copying data/open_images/validation/data/7588a6de389ac33a.jpg to data/open_images_extracted/not_food_images/7588a6de389ac33a.jpg...
# Copying data/open_images/train/data/2756ffd65d2e20e1.jpg to data/open_images_extracted/not_food_images/2756ffd65d2e20e1.jpg...
# Copying data/open_images/test/data/03bb23f4c215f9c8.jpg to data/open_images_extracted/not_food_images/03bb23f4c215f9c8.jpg...
# Copying data/open_images/test/data/65fbccdd5c1071a3.jpg to data/open_images_extracted/not_food_images/65fbccdd5c1071a3.jpg...
# Total not_food images copied: 267

# %%
for dir, subdirs, files in os.walk("data/open_images_extracted/"):
    for subdir in subdirs:
        print(f"Total {subdir} images: {len(os.listdir(os.path.join(dir, subdir)))}")
# Out:
# Total food_images images: 29
# Total not_food_images images: 267
